# %%
import pandas as pd
import numpy as np
import tweepy
import requests
import requests_cache

requests_cache.install_cache('demo_cache')

# %%
df = pd.read_csv('/Users/Aaron/Desktop/STA160/First data set/datasets_full.csv/genuine_accounts.csv/users.csv')
names = list(df.columns.values)

# %%
CONSUMER_KEY = 'QifrSmYAQ2mjIf8kiPoL2kI4v'
CONSUMER_SECRET = 'qHXPmXDd4Gw2cqZ5zKmDpU6drKEHTF396pj9qyoUYWDcLsFOlm'
ACCESS_TOKEN = '3379234805-hUmhUJa0oV9V1mnKDuB6bitJ1QTEjdq2c9zE0RA'
ACCESS_TOKEN_SECRET = 'cQiqDWDuoLj8SH68d6JuPhthToImk3WzmcQ3pbyxYfYK1'

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth)

# %%
user = api.get_user(1502026416)

# %%
get_var = [user.id, user.name, user.screen_name, user.statuses_count, user.followers_count, user.friends_count, user.favourites_count,
    user.listed_count, user.url, user.lang, user.time_zone, user.location, user.default_profile, user.default_profile_image,
    user.geo_enabled, user.profile_image_url, user.profile_banner_url, user.profile_use_background_image, user.profile_background_image_url_https,
    user.profile_text_color, user.profile_image_url_https, user.profile_sidebar_border_color, user.profile_background_tile,
    user.profile_sidebar_fill_color, user.profile_background_image_url, user.profile_background_color, user.profile_link_color,
    user.utc_offset, user.is_translator,user.follow_request_sent, user.protected, user.verified, user.notifications,
    user.description, user.contributors_enabled, user.following, user.created_at]

# %%
#pd.DataFrame(get_var)
get_var
# Out:
# [1502026416,
#  u'\u65e9\u5ddd\u63f4',
#  u'0918Bask',
#  3431,
#  286,
#  441,
#  586,
#  0,
#  None,
#  u'ja',
#  None,
#  u'',
#  False,
#  False,
#  True,
#  u'http://pbs.twimg.com/profile_images/800648534760402945/uJ-sqkHK_normal.jpg',
#  u'https://pbs.twimg.com/profile_banners/1502026416/1479483793',
#  False,
#  u'https://abs.twimg.com/images/themes/theme1/bg.png',
#  u'000000',
#  u'https://pbs.twimg.com/profile_images/800648534760402945/uJ-sqkHK_normal.jpg',
#  u'000000',
#  False,
#  u'000000',
#  u'http://abs.twimg.com/images/themes/theme1/bg.png',
#  u'000000',
#  u'EB0C1F',
#  None,
#  False,
#  False,
#  False,
#  False,
#  False,
#  u'motorcycle.&car.',
#  False,
#  False,
#  datetime.datetime(2013, 6, 11, 11, 20, 35)]

# %%
list(df['id'])
# Out:
# [1502026416,
#  2492782375,
#  293212315,
#  191839658,
#  3020965143,
#  2157382005,
#  1947320929,
#  255846106,
#  1733095801,
#  1336097480,
#  380322177,
#  32988810,
#  21959183,
#  1553611423,
#  348080571,
#  839690880,
#  143687056,
#  2291421004,
#  2337494094,
#  225241810,
#  375114767,
#  52929021,
#  1657000316,
#  325967359,
#  585912212,
#  2419936286,
#  2320414572,
#  262531823,
#  226315121,
#  492649414,
#  56554591,
#  85193539,
#  166211662,
#  222290847,
#  2765166293,
#  2497379616,
#  69991603,
#  357747403,
#  430285181,
#  1141299306,
#  37407255,
#  112295272,
#  208664282,
#  348393966,
#  1245621752,
#  329481796,
#  131043638,
#  150183040,
#  91287122,
#  2244762307,
#  344457551,
#  2360378178,
#  398467095,
#  2400711853,
#  32494880,
#  2362812823,
#  509255384,
#  86565348,
#  250207934,
#  238040058,
#  476876406,
#  190345460,
#  1376257824,
#  714550385,
#  474152548,
#  1373517728,
#  177906959,
#  2248762537,
#  462534253,
#  93941188,
#  22437394,
#  1195136336,
#  1956659528,
#  1175224910,
#  578904059,
#  454183646,
#  318040219,
#  558782771,
#  1425572605,
#  103668192,
#  50034798,
#  2574200442,
#  53114456,
#  1495594020,
#  1387377110,
#  1892545526,
#  489714722,
#  278811330,
#  64534012,
#  138472981,
#  1727495887,
#  440901699,
#  185216671,
#  32831822,
#  2938551012,
#  241347721,
#  20301520,
#  1191129162,
#  49709134,
#  58797847,
#  392080330,
#  1120863444,
#  1261040287,
#  2257926470,
#  96815122,
#  120833703,
#  58477691,
#  22798846,
#  381753637,
#  2718118608,
#  581233948,
#  1194760087,
#  3140424071,
#  434832511,
#  517639654,
#  468080275,
#  622956477,
#  149723283,
#  742326175,
#  2311184364,
#  2251878995,
#  2378140945,
#  519445792,
#  2920448851,
#  252882696,
#  41950696,
#  2941150861,
#  2204112777,
#  484522355,
#  1874015534,
#  59689509,
#  1897930380,
#  58702972,
#  508355849,
#  3164941860,
#  110122113,
#  866157062,
#  231257304,
#  884366718,
#  208913421,
#  229875064,
#  341900539,
#  136245387,
#  745638440,
#  1544322560,
#  1505023116,
#  119112245,
#  368134512,
#  485384525,
#  2152052819,
#  634704287,
#  2557136665,
#  92999280,
#  372835779,
#  1858934186,
#  282427769,
#  40219052,
#  1408912964,
#  40008819,
#  777083114,
#  24080811,
#  990963038,
#  448697610,
#  110928853,
#  54552304,
#  2772354013,
#  2799099042,
#  400983194,
#  497404180,
#  14587971,
#  3022543596,
#  121976265,
#  2914171005,
#  2644167680,
#  33764583,
#  223345906,
#  420189045,
#  1668189836,
#  375299270,
#  23444554,
#  1465761582,
#  44686891,
#  2561813863,
#  2445641666,
#  344317888,
#  2511944460,
#  2618119582,
#  88345204,
#  2214453095,
#  221475117,
#  26528107,
#  101669097,
#  2977924797,
#  2317599350,
#  165077100,
#  2202044150,
#  73237856,
#  2356425746,
#  3018260990,
#  1135530474,
#  834680701,
#  3007481400,
#  235696520,
#  2257069046,
#  5812422,
#  1086489391,
#  2294138446,
#  19325141,
#  2596423866,
#  100837759,
#  887505716,
#  80477690,
#  250364288,
#  2302538826,
#  505440359,
#  3033858666,
#  121268938,
#  573301009,
#  1456643797,
#  56032903,
#  1536909666,
#  300264746,
#  344261687,
#  19849696,
#  1057635702,
#  2290983830,
#  713804306,
#  613345676,
#  1499931151,
#  17801629,
#  157029836,
#  26203719,
#  933183398,
#  299271462,
#  888320442,
#  266794738,
#  498418001,
#  2347977979,
#  2223611410,
#  330169460,
#  2210140580,
#  21257459,
#  874719912,
#  2778387798,
#  23808818,
#  79894962,
#  11630862,
#  635818294,
#  614447598,
#  485273674,
#  169194549,
#  2563768914,
#  990902802,
#  1376920032,
#  442079113,
#  456357565,
#  461572767,
#  722623,
#  139956067,
#  18989002,
#  359219562,
#  147474106,
#  902817020,
#  18581153,
#  275931291,
#  578481944,
#  208388521,
#  457808323,
#  2200425967,
#  2785200258,
#  553317912,
#  2444483352,
#  170554164,
#  563333511,
#  620078665,
#  836742500,
#  2243809497,
#  18576332,
#  528006498,
#  798613004,
#  413675359,
#  985768968,
#  3010585944,
#  428628035,
#  19300510,
#  14247395,
#  763095612,
#  2382912776,
#  747385746,
#  33651270,
#  1311456667,
#  304261771,
#  1093553114,
#  282506597,
#  193609769,
#  367414177,
#  403783820,
#  2224804969,
#  468308770,
#  1877304734,
#  16484437,
#  35377886,
#  2183434100,
#  568015457,
#  57549666,
#  30059111,
#  708043502,
#  153690249,
#  2828821663,
#  44850701,
#  1528172522,
#  1032838123,
#  2508074020,
#  2259016411,
#  1561409924,
#  764731350,
#  2694552757,
#  113231814,
#  250399342,
#  16944013,
#  368801289,
#  1107989989,
#  45449023,
#  1705146012,
#  2159485357,
#  1353072290,
#  333005444,
#  323494341,
#  492728332,
#  630413999,
#  589834497,
#  227133540,
#  1226238145,
#  469595996,
#  2983156296,
#  250549433,
#  2367477707,
#  42244063,
#  1578395316,
#  94735361,
#  1670962238,
#  14391111,
#  236449587,
#  2654027174,
#  421391363,
#  228978063,
#  2402922414,
#  1333119788,
#  450939144,
#  25121744,
#  2448332095,
#  2423000125,
#  540416380,
#  525965404,
#  471512676,
#  43897661,
#  506892551,
#  889661521,
#  190114317,
#  161662393,
#  22201064,
#  57572464,
#  771812148,
#  967352869,
#  124359379,
#  1280865181,
#  225683965,
#  1557371234,
#  144074129,
#  109139576,
#  380143624,
#  706364737,
#  1686842737,
#  270654915,
#  9272142,
#  602307139,
#  3048199577,
#  2868402013,
#  546533556,
#  961709562,
#  210704864,
#  469739735,
#  621021228,
#  2781727178,
#  143217021,
#  528800946,
#  745579297,
#  2697960505,
#  2991390654,
#  194476539,
#  3061358054,
#  2424503989,
#  451144632,
#  2735881390,
#  198249025,
#  421577024,
#  59230786,
#  546312443,
#  80119212,
#  27372659,
#  872703248,
#  1549052863,
#  127037804,
#  1424238228,
#  78989741,
#  298742535,
#  165277911,
#  2882736641,
#  15805367,
#  220467586,
#  232547074,
#  535758794,
#  48552476,
#  2770511,
#  490440829,
#  542231259,
#  1435964180,
#  69379288,
#  248453338,
#  28088585,
#  225248989,
#  838827888,
#  406510798,
#  2903346739,
#  1468885260,
#  524913626,
#  428641140,
#  1338216625,
#  402131078,
#  304684588,
#  612129754,
#  96297290,
#  157158598,
#  42580296,
#  266560801,
#  545261627,
#  2461920925,
#  1546896846,
#  83159701,
#  101557278,
#  409593977,
#  56337417,
#  26192354,
#  1093261646,
#  2325931652,
#  2242993111,
#  2916170922,
#  532556025,
#  587271182,
#  547900413,
#  56321548,
#  79328703,
#  1272060360,
#  46841328,
#  463045937,
#  243850570,
#  1190881465,
#  403782011,
#  1398673159,
#  632368135,
#  64965325,
#  1853487314,
#  20307019,
#  392349274,
#  1319639179,
#  563452765,
#  2379422593,
#  3026783043,
#  2841853914,
#  2899116833,
#  616602934,
#  98199469,
#  1944581808,
#  259849575,
#  1390147280,
#  434818530,
#  2380148790,
#  517160489,
#  2455018318,
#  297310680,
#  503262878,
#  54546468,
#  465013390,
#  245307045,
#  1693274954,
#  215982940,
#  2799937080,
#  238588883,
#  138637933,
#  1094680927,
#  1079378204,
#  43476480,
#  323258441,
#  1438656991,
#  23132833,
#  72060994,
#  1282062985,
#  3042955211,
#  397983328,
#  1318895588,
#  149421076,
#  980981264,
#  2587768189,
#  341396015,
#  1659710504,
#  3027627954,
#  29267129,
#  574809536,
#  1852825657,
#  77441233,
#  949432574,
#  208147488,
#  632503479,
#  206329613,
#  769339466,
#  402917643,
#  2562390674,
#  266900678,
#  938206194,
#  17283343,
#  2233856637,
#  15224719,
#  749593849,
#  19368233,
#  2223969871,
#  1073409068,
#  172229393,
#  427791119,
#  352883693,
#  368766578,
#  2349866700,
#  296606221,
#  443907895,
#  321465766,
#  707697690,
#  1301940242,
#  95463236,
#  217502590,
#  33950491,
#  110118205,
#  330896147,
#  599736873,
#  1579380864,
#  512918460,
#  2168701743,
#  345735870,
#  3130618992,
#  202431280,
#  2768602538,
#  2268198534,
#  34308947,
#  410165126,
#  2193434506,
#  294078783,
#  176688197,
#  1715241043,
#  21671968,
#  315478329,
#  311835878,
#  407770732,
#  29552151,
#  211397444,
#  3054738993,
#  948824810,
#  548938182,
#  296465140,
#  333722906,
#  2166124159,
#  294562734,
#  1021352646,
#  114910555,
#  306548180,
#  910519015,
#  147900782,
#  303484324,
#  106787019,
#  571300130,
#  571602303,
#  576967621,
#  317296274,
#  621429721,
#  1560481692,
#  1027713949,
#  148061189,
#  149512577,
#  704048113,
#  391796089,
#  2762444463,
#  32688131,
#  2245115129,
#  2877567647,
#  2387366902,
#  169035707,
#  322865349,
#  96319587,
#  83285256,
#  2220325358,
#  288923751,
#  1144331803,
#  1152779738,
#  243819894,
#  2376957437,
#  328145177,
#  83296294,
#  243926487,
#  81437114,
#  1307962584,
#  248827763,
#  2499922645,
#  2166840403,
#  1095345769,
#  324487766,
#  2514604339,
#  116537112,
#  839486461,
#  1936513045,
#  74785094,
#  30146653,
#  236809977,
#  220450406,
#  17520304,
#  52660118,
#  1289744306,
#  2402142792,
#  142074569,
#  1340696474,
#  201113766,
#  40831469,
#  175108392,
#  2543328276,
#  482865517,
#  141977425,
#  2456001787,
#  272264836,
#  349152819,
#  58649802,
#  531007524,
#  2955767954,
#  2595828119,
#  2994985944,
#  93821152,
#  1616084173,
#  595827319,
#  68915174,
#  387026133,
#  2891962836,
#  1082033923,
#  53389180,
#  1890978697,
#  1260499758,
#  17455999,
#  709885621,
#  291570117,
#  33696967,
#  2562161460,
#  1413677126,
#  1712224658,
#  1321389582,
#  358976197,
#  47479923,
#  524809586,
#  28758925,
#  18192239,
#  400896343,
#  756433608,
#  32289927,
#  2856367704,
#  804830348,
#  2207144936,
#  135192904,
#  85677419,
#  1543392469,
#  1607411708,
#  35551388,
#  393480403,
#  2738679910,
#  162018954,
#  532840492,
#  541506684,
#  299990409,
#  122205252,
#  2832903374,
#  127895572,
#  2670730536,
#  2549701596,
#  753906162,
#  593100391,
#  1269622489,
#  22951310,
#  29396889,
#  284102132,
#  481505805,
#  708035550,
#  2983371691,
#  348885670,
#  123209387,
#  1671101821,
#  1465100186,
#  1729686344,
#  51625730,
#  865789586,
#  33411297,
#  2850494395,
#  1392517694,
#  452817554,
#  823241647,
#  1411660735,
#  361943550,
#  2595110809,
#  263920631,
#  261781756,
#  45627569,
#  1104076022,
#  1065027181,
#  594142749,
#  86235989,
#  245812733,
#  486111271,
#  27244453,
#  86805382,
#  26683817,
#  2482076730,
#  18510639,
#  102895387,
#  2323069159,
#  24197313,
#  412754103,
#  424328175,
#  2941279177,
#  2218308561,
#  603047832,
#  28757342,
#  222617763,
#  40897354,
#  333078665,
#  1114707913,
#  53308462,
#  568388087,
#  2334997532,
#  2193685661,
#  335080461,
#  128266623,
#  2971533842,
#  1527066073,
#  363991245,
#  21714748,
#  152077459,
#  636764655,
#  58983782,
#  545516275,
#  33726503,
#  32628646,
#  91823642,
#  51465730,
#  969199590,
#  270752804,
#  2290521421,
#  433559911,
#  146252687,
#  2398614422,
#  913855980,
#  375871540,
#  297808691,
#  27014940,
#  363309757,
#  2169418620,
#  167099444,
#  23413533,
#  624223536,
#  2287761206,
#  546074374,
#  612832024,
#  252595286,
#  159691975,
#  216112755,
#  574566147,
#  898427606,
#  455802121,
#  405970201,
#  392963387,
#  1370908110,
#  27493957,
#  1535051239,
#  1690030831,
#  882866095,
#  2425786212,
#  1408968848,
#  573246139,
#  2265815350,
#  315458934,
#  104960620,
#  1347167636,
#  2290332602,
#  50252197,
#  1136566969,
#  2987929881,
#  1715023975,
#  2505586309,
#  143405692,
#  636709756,
#  2240095033,
#  375777649,
#  1539759007,
#  1689315170,
#  282616462,
#  2433146611,
#  21253156,
#  624058980,
#  2408175668,
#  366407174,
#  1648972316,
#  2460935354,
#  472301455,
#  2927086706,
#  1403795054,
#  422839809,
#  2937792273,
#  70557274,
#  85826876,
#  392385320,
#  343749080,
#  182276961,
#  413056775,
#  1392978859,
#  14982885,
#  98596642,
#  243060684,
#  1321364888,
#  35942782,
#  281711633,
#  1232534634,
#  36874110,
#  78967328,
#  339444631,
#  221187678,
#  49691940,
#  1069354226,
#  1116301764,
#  446905532,
#  430979463,
#  2285711065,
#  14307043,
#  604176461,
#  1200888036,
#  430588488,
#  2156476916,
#  15888676,
#  2680793168,
#  156751025,
#  2157979582,
#  1321733300,
#  391650964,
#  1654056680,
#  1646872513,
#  2717096415,
#  536234966,
#  797268164,
#  539977804,
#  291594394,
#  101098094,
#  233444535,
#  520328342,
#  2594420244,
#  887026338,
#  2719640706,
#  2911861962,
#  66789784,
#  495020496,
#  1476770959,
#  316120129,
#  183765902,
#  477542555,
#  3042681007,
#  232678324,
#  619201618,
#  1637563074,
#  1381970808,
#  2374759993,
#  2238512887,
#  428421268,
#  2956613720,
#  2157249587,
#  19478719,
#  58292961,
#  251905557,
#  1161256308,
#  3084357732,
#  186978312,
#  546096491,
#  1433206302,
#  99716926,
#  2907385266,
#  332829606,
#  2174730115,
#  3888491,
#  3037199234,
#  599745022,
#  219404734,
#  1023331706,
#  625400643,
#  215533065,
#  85067793,
#  14235705,
#  108701807,
#  429789520,
#  60278487,
#  83390456,
#  564336147,
#  242205664,
#  1478592602,
#  3054142278,
#  300374583,
#  1041326394,
#  2596834903,
#  3116708222,
#  65984518,
#  128111467,
#  241157629,
#  726729494,
#  707660496,
#  77558505,
#  369285103,
#  2596494170,
#  208200663,
#  541711129,
#  3087465981,
#  251633570,
#  42401379,
#  456150594,
#  25693756,
#  352944559,
#  901659314,
#  140717029,
#  555411470,
#  2250794221,
#  571579758,
#  426334161,
#  213261669,
#  28340717,
#  85841150,
#  811928833,
#  256256185,
#  21281949,
#  455950099,
#  2510903360,
#  2347768868,
#  46961288,
#  1736045779,
#  57376225,
#  120705454,
#  407225208,
#  2158122428,
#  1167773802,
#  3037256261,
#  97484136,
#  1082117736,
#  1478531461,
#  30750923,
#  559486409,
#  188961582,
#  317273582,
#  1083991861,
#  40502358,
#  954799494,
#  139250696,
#  1672205587,
#  2555419261,
#  35941580,
#  274285556,
#  1620466530,
#  2668485740,
#  18463828,
#  309132692,
#  1343220962,
#  40812882,
#  2484023400,
#  481994964,
#  760936026,
#  63986474,
#  541142436,
#  29867936,
#  289732005,
#  554242271,
#  141223622,
#  999662546,
#  2994255158,
#  3069153899,
#  2886779494,
#  93127862,
#  14791386,
#  253339095,
#  1723943414,
#  50357236,
#  2377001464,
#  1016015984,
#  57591732,
#  343120924,
#  108135829,
#  81186711,
#  2840265139,
#  ...]
