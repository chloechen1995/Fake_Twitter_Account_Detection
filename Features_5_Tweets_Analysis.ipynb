# %% [markdown]
# ## Content-based Feature
# <li>The percentage of Tweets containing URLs</li>
# <li>The ratio of the number of unique URLs [3]</li>
# <li>hashtag ratio</li>
# <li>The ratio of the number of @usernames [3]</li>
# <li>The ratio of the number of unique @usernames [3]</li>
# <li>Tweet similarity:
# (1) $S=\frac{\sum_{p\in P}c(p)}{l_al_p}$
# where $P$ is the set of possible tweet-to-tweet combinations among any two tweets logged for a certain account, $p$ is a single pair, $c(p)$ is a function calculation the number of words two tweets share, $l_a$ is the average length of tweets posted by that user, and $l_p$ is the number of tweet combinations. A profile sending similar tweets will have a low value of S.[4]
# (2) $\sum_{a,b \in set of pairs in tweets}\frac{similarity(a,b)}{|set of pairs in tweets|}$
# where the content similarity is computed using the standard cosine simility over the bag-of-word vector representation $\mathbf{V(a)}$ of the tweet content: $similarity(a,b)=\frac{\mathbf{V(a)}\mathbf{V(b)}}{|\mathbf{V(a)}||\mathbf{V(b)}|}$
# Since tweets are extremely short (140 characters or less), we consider a bag-of-words model and a sparse bigrams model. [3]</li>
# <li>Duplicate tweet count</li>
# <li>User behavior: number of times the user was mentioned, number of times the user was replied to, number of times the user replied someone</li>

# %%
import pandas as pd
import numpy as np
import tweepy
import requests
import requests_cache
import time
requests_cache.install_cache('demo_cache')
from api import *
import re
from __future__ import division
from compiler.ast import flatten
from math import factorial
from nltk.corpus import stopwords
import glob
import csv

# %%
# read all the files
genuine = pd.read_csv(open('User dataset/genuine account.csv', 'rU'), 
                      encoding = 'utf-8', usecols = ['id'] )

# load in fake accounts data
path =r'./User dataset/fake data/'
allFiles = glob.glob(path + "/*.csv")
fake = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(open(file_, 'rU'), encoding = 'utf-8', usecols = ['id'])
    list_.append(df)
fake = pd.concat(list_)
# merge all the data 
all_ids = pd.concat([genuine, fake])

# %%
# create a list of user ids
id_list = list(all_ids['id'])
id_list = [str(i) for i in id_list]
items = ["False", "None", "nan"]
id_list = filter(lambda x: x not in items, id_list)
final_id_list = [int(i) for i in id_list]

# %%
def get_tweets_limit(id_list):
    
    """
    gets the most recent 200 tweets from a user timeline
    
    Argument: a list of twitter id
    
    Return: a tweets dataframe
    """
    # create a list that stores the tweets for all the users
    all_tweets = []
    for twitter_id in id_list:
        # read the tweets from the timeline, 200 is the maximum allowed count
        tweets = api.user_timeline(user_id = twitter_id,count = 200)
         # save the tweets into the list
        tweets_list = []
        tweets_list.extend(tweets)
        outtweets = [[tweet.id_str, tweet.created_at, tweet.source, tweet.text.encode("utf-8")] for tweet in tweets_list]
        tweets = [tweets + [twitter_id] for tweets in outtweets]
        all_tweets.extend(tweets)
    tweets_df = pd.DataFrame(all_tweets)
    col_names = ['tweet_id', 'tweet_created_at', 'tweet_source', 'tweet_text', 'twitter_id']
    tweets_df.columns = col_names
    return tweets_df

# %%
def create_tweets_df(user_file):
    """
    create a dataframe that stores the existing user tweets
    
    Argument: the user info dataframe
    
    Return: a tweets dataframe
    """
    user_df = pd.read_csv("User_dataset/" + user_file)
    twitter_id = list(user_df['id'])
    tweets_df = get_tweets_limit(twitter_id)
    return tweets_df

# %%
# Use reference: https://gist.github.com/yanofsky/5436496#file-tweet_dumper-py

def get_all_tweets(twitter_id):
    all_tweets = []
    tweets = api.user_timeline(user_id = twitter_id,count = 200)
    all_tweets.extend(tweets)
    oldest = all_tweets[-1].id - 1
    while len(tweets) > 0:
        tweets = api.user_timeline(user_id = twitter_id,count = 200, max_id = oldest)
        all_tweets.extend(tweets)
        oldest = all_tweets[-1].id - 1
    outtweets = [[tweet.id_str, tweet.created_at, tweet.source, tweet.text.encode("utf-8")] for tweet in all_tweets]
    tweets = [tweets + [twitter_id] for tweets in outtweets]
    with open('%s_tweets.csv' % twitter_id, 'wb') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","source","tweet_text", "id"])
        writer.writerows(tweets)
    
    pass

# %%
get_all_tweets(33212890)

# %% [markdown]
# Reference: http://www.cs.wm.edu/~hnw/paper/tdsc12b.pdf
#
# The users post tweets manually or via auto piloted tools.
#
# Devices are divided in the following categories:
#
# 1) Twitter Web Client
#
# 2) Mobile Devices: Android and OS
#
# 3) Registered third-party applications: website integrators(twitpic, bit.ly, Facebook, Tweetbar, Twitterfox for Firefox, Desktop clients(TweetDeck and Seesmic Desktop), RSS feeds/blog widgets(twitterfeed and Twitter for Wordpress)
#
# 4) APIs, third-party applications not registered or certified by Twitter, labeled as API

# %%
# genuine
get_tweets_limit([2492782375, 293212315])
# Out:
#                tweet_id    tweet_created_at        tweet_source  \
# 0    860434971432964096 2017-05-05 10:04:17  Twitter for iPhone
# 1    860245821119320064 2017-05-04 21:32:41  Twitter for iPhone
# 2    860243247825772544 2017-05-04 21:22:27  Twitter for iPhone
# 3    860242909588631552 2017-05-04 21:21:06  Twitter for iPhone
# 4    859520657855467521 2017-05-02 21:31:08  Twitter for iPhone
# 5    859280547377422337 2017-05-02 05:37:01  Twitter Web Client
# 6    858935817628024832 2017-05-01 06:47:11  Twitter for iPhone
# 7    858363690512400385 2017-04-29 16:53:46  Twitter Web Client
# 8    858067988112523264 2017-04-28 21:18:45  Twitter for iPhone
# 9    858065248451870720 2017-04-28 21:07:51  Twitter for iPhone
# 10   858064324954214400 2017-04-28 21:04:11  Twitter for iPhone
# 11   857773655639457792 2017-04-28 01:49:10  Twitter for iPhone
# 12   857588973819932673 2017-04-27 13:35:19  Twitter for iPhone
# 13   857345082910851072 2017-04-26 21:26:11  Twitter for iPhone
# 14   857344385041563648 2017-04-26 21:23:24  Twitter for iPhone
# 15   856864496182329344 2017-04-25 13:36:30  Twitter for iPhone
# 16   856864312232734721 2017-04-25 13:35:46  Twitter for iPhone
# 17   856492562172989440 2017-04-24 12:58:34  Twitter for iPhone
# 18   856492445650923520 2017-04-24 12:58:06  Twitter for iPhone
# 19   856320416717066240 2017-04-24 01:34:31  Twitter for iPhone
# 20   856142112538021888 2017-04-23 13:46:00  Twitter for iPhone
# 21   856140075926667265 2017-04-23 13:37:55  Twitter for iPhone
# 22   855416567445692416 2017-04-21 13:42:57  Twitter for iPhone
# 23   855171728250609668 2017-04-20 21:30:02  Twitter for iPhone
# 24   855025068786593793 2017-04-20 11:47:16  Twitter for iPhone
# 25   854976441728999425 2017-04-20 08:34:03  Twitter for iPhone
# 26   854934247970189312 2017-04-20 05:46:23  Twitter for iPhone
# 27   854446082914267136 2017-04-18 21:26:35  Twitter for iPhone
# 28   854445601122951168 2017-04-18 21:24:40  Twitter for iPhone
# 29   854445530331721731 2017-04-18 21:24:23  Twitter for iPhone
# ..                  ...                 ...                 ...
# 367  668157011108851716 2015-11-21 20:00:19  Twitter for iPhone
# 368  668156995506073601 2015-11-21 20:00:16  Twitter for iPhone
# 369  668155678138109954 2015-11-21 19:55:02  Twitter for iPhone
# 370  668155514375684096 2015-11-21 19:54:23  Twitter for iPhone
# 371  668140145401446400 2015-11-21 18:53:18  Twitter for iPhone
# 372  668124442539589632 2015-11-21 17:50:54  Twitter for iPhone
# 373  667763972263665665 2015-11-20 17:58:32  Twitter for iPhone
# 374  667763750850596864 2015-11-20 17:57:39  Twitter for iPhone
# 375  667763501704712192 2015-11-20 17:56:39  Twitter for iPhone
# 376  667703449799098370 2015-11-20 13:58:02  Twitter for iPhone
# 377  667549320783069185 2015-11-20 03:45:35  Twitter for iPhone
# 378  667490649143312384 2015-11-19 23:52:26  Twitter for iPhone
# 379  667176566326083584 2015-11-19 03:04:23  Twitter for iPhone
# 380  667120211464617984 2015-11-18 23:20:27  Twitter for iPhone
# 381  667102232555319297 2015-11-18 22:09:01  Twitter for iPhone
# 382  666967488379412480 2015-11-18 13:13:35  Twitter for iPhone
# 383  666967468825530369 2015-11-18 13:13:30  Twitter for iPhone
# 384  666814310472003585 2015-11-18 03:04:55  Twitter for iPhone
# 385  666812421764481024 2015-11-18 02:57:24  Twitter for iPhone
# 386  666811515094347776 2015-11-18 02:53:48  Twitter for iPhone
# 387  666780899002814464 2015-11-18 00:52:09  Twitter for iPhone
# 388  666780481967427584 2015-11-18 00:50:29  Twitter for iPhone
# 389  666779783997468672 2015-11-18 00:47:43  Twitter for iPhone
# 390  666423080995000321 2015-11-17 01:10:18  Twitter for iPhone
# 391  666036553643241472 2015-11-15 23:34:23  Twitter for iPhone
# 392  666028073729458176 2015-11-15 23:00:41  Twitter for iPhone
# 393  666026654154657792 2015-11-15 22:55:03  Twitter for iPhone
# 394  666025734205407233 2015-11-15 22:51:23  Twitter for iPhone
# 395  666023805307875328 2015-11-15 22:43:43  Twitter for iPhone
# 396  666020800089067520 2015-11-15 22:31:47  Twitter for iPhone
#
#                                             tweet_text  twitter_id
# 0    RT @Afro_spirits: そもそも財政難ではない。 https://t.co/8x...  2492782375
# 1    RT @namiheiAMURO: 人手不足というのは、現在の賃金が低すぎて、超過需要が生じ...  2492782375
# 2                       奴らにとって憲法典は聖遺物とかモノリスみたいなモンなんでしょ  2492782375
# 3    RT @mollichane: 憲法学者と言う人種がいかにデタラメか分かる図。\n図１の「自...  2492782375
# 4    RT @saitohisanori: 「私が金融緩和を始めたとき株がバブルになるとかドルが暴...  2492782375
# 5    RT @kyounoowari: 物価が再び下落する中、保険という詐欺みたいな言葉で増税主張...  2492782375
# 6    RT @kokoro_gif_bot: #心が乱れた時に見るgif\nケルベロス型加湿器！？...  2492782375
# 7    RT @Pekaso: 講師「業務中に疑問に思ったことを何でも良いので思い浮かべてください」...  2492782375
# 8    RT @Black_Post_Bot: 身の回りにブラック企業が溢れているから忘れがちだけど...  2492782375
# 9    RT @washizutan: 取引先の担当者で、新人の事務員ちゃんにPCの使い方教えてると...  2492782375
# 10   RT @oprosedust: 金融緩和強めろ\n国民負担一切増やすな\n(増税、社会保険料...  2492782375
# 11   RT @Afro_spirits: 統合政府のバランスシートも作成いたしました。\n統合政府...  2492782375
# 12   RT @shin72826: 【朗報】大の仲良し筒香＆中田翔、同じ日に今季第1号ホームランを...  2492782375
# 13   RT @shio_hnkn: 母が今頃けものフレンズにハマって家でずっとようこそジャパリパー...  2492782375
# 14   RT @Black_Post_Bot: 自分の仕事大好きで進んで残業したり成果をバンバンあげ...  2492782375
# 15                                         良いジョークだ（憤怒）  2492782375
# 16   RT @yuh_rasia: 今日の読売新聞、笑いしか出ない https://t.co/P6...  2492782375
# 17   RT @kengonart: 10代の疑問「消費税は上がるの？」に、おときた駿都議がトンデモ...  2492782375
# 18   RT @smith796000: おときたさん残念。「ヤバいと思い始めたら云々」というのは岩...  2492782375
# 19   RT @dqndoc1019: 「労働生産性が低いのは、経済政策の失敗でGDPが伸びなかった...  2492782375
# 20   RT @kuri_kurita: 消費税なんてシステム自体が間違いだったんだから、さっさと廃...  2492782375
# 21   RT @kiba_r: どいつもこいつも、戦う相手を間違えすぎ。\n\n正しいマクロ経済政策...  2492782375
# 22   RT @gdp_target: 主流派やデフレ派にイラつく理由のひとつは、失業を甘く見すぎて...  2492782375
# 23   RT @military1964: 射出座席が無いころは、脱出するさいに尾翼にぶつかり死亡す...  2492782375
# 24   RT @medical_for_all: 時給1500円論争がありますが、\n実際の所は「市...  2492782375
# 25   RT @kiba_r: 完全に財務省のスピーカーだな。\n\n／／…ヘリコプターマネー導入せ...  2492782375
# 26   RT @YES777777777: 【職務放棄する税金ドロボー】衆院・法務委でのテロ等準備罪...  2492782375
# 27   RT @Y_Kaneko: 日銀審議委員に三菱ＵＦＪリサーチの片岡剛士氏との報道。まさに適材...  2492782375
# 28                                            マジならヤバすぎ  2492782375
# 29   RT @YuzhanL: 就職の面接を受けた。「もし給料が支払われなかったらどうする？」と聞...  2492782375
# ..                                                 ...         ...
# 367  RT @chelsbewright: @keke_brooke oh smart girl ...   293212315
# 368                 @chelsbewright no! But I will now!   293212315
# 369       @chelsbewright I've already seen them 😅😂😂   293212315
# 370   @parker_v2 come on over! https://t.co/Bv9AFz5up0   293212315
# 371            What's a good show to start on Netflix?   293212315
# 372  If anyone comes to Tejas I will personally buy...   293212315
# 373  RT @tinatbh: *on a first date*\nok dont let th...   293212315
# 374  RT @tinatbh: I embarrass myself in front of my...   293212315
# 375        RT @tinatbh: its ok\n\nill text myself back   293212315
# 376  RT @dustbash: Guess I won't be listening to @A...   293212315
# 377  RT @awkwardgoogle: How come I never thought ab...   293212315
# 378  I have subtweeted once that I know of..😳\nExc...   293212315
# 379  RT @MedievaI_React: When someone waves in your...   293212315
# 380  RT @1TaylorAllen: @keke_brooke @parker_v2 @Rea...   293212315
# 381  @parker_v2 Chelsea Morris already created fait...   293212315
# 382  RT @april_beaster: @keke_brooke The Longest Ri...   293212315
# 383                              @oakleydrew16 both 😂   293212315
# 384                        @gillianbashaw_ always 😘😘   293212315
# 385  RT @BieberBonerz: I could literally listen to ...   293212315
# 386        I think I'm going to start traveling again.   293212315
# 387                         What movie should I watch?   293212315
# 388  RT @FemalePains: When you find the right dress...   293212315
# 389  RT @ThatBucketList: November be like https://t...   293212315
# 390  RT @ItsJennaMarbles: Me after I send a stupid ...   293212315
# 391     @parker_v2 thanks for looking out!!!!!!!!!!!!!   293212315
# 392  I need a group of friends to check all of my t...   293212315
# 393  When your grammar is just so bad auto correct ...   293212315
# 394  Compliment someone today! It might not mean an...   293212315
# 395           It's the small things that can be so big   293212315
# 396  RT @RelatableQuote: IM CRYING this movie looks...   293212315
#
# [397 rows x 5 columns]

# %%
# fake
get_tweets_limit([24858289, 33212890])
# Out:
#                tweet_id    tweet_created_at        tweet_source  \
# 0    860374756788494336 2017-05-05 06:05:01            Facebook
# 1    860203786660458500 2017-05-04 18:45:39            Facebook
# 2    860192258926235648 2017-05-04 17:59:50            Facebook
# 3    860174783979368448 2017-05-04 16:50:24                Waze
# 4    860095488154116096 2017-05-04 11:35:18            Facebook
# 5    860091656938377216 2017-05-04 11:20:05            Facebook
# 6    860007135513649153 2017-05-04 05:44:13                Waze
# 7    860005782548602880 2017-05-04 05:38:51                Waze
# 8    859837992470552584 2017-05-03 18:32:07            Facebook
# 9    859835250503012352 2017-05-03 18:21:13            Facebook
# 10   859644979131580418 2017-05-03 05:45:09            Facebook
# 11   859639436367233025 2017-05-03 05:23:07            Facebook
# 12   859619044097392640 2017-05-03 04:02:05            Facebook
# 13   859618776656093184 2017-05-03 04:01:01            Facebook
# 14   859469719061004289 2017-05-02 18:08:43            Facebook
# 15   859272971323682816 2017-05-02 05:06:55            Facebook
# 16   859272931356155905 2017-05-02 05:06:46            Facebook
# 17   859236256760434688 2017-05-02 02:41:02            Facebook
# 18   859235294708727809 2017-05-02 02:37:12            Facebook
# 19   859116572929077249 2017-05-01 18:45:27            Facebook
# 20   859115794331992065 2017-05-01 18:42:21            Facebook
# 21   859014592990720001 2017-05-01 12:00:13            Facebook
# 22   858940603194847232 2017-05-01 07:06:12            Facebook
# 23   858940350731309056 2017-05-01 07:05:12            Facebook
# 24   858744481755037697 2017-04-30 18:06:53            Facebook
# 25   858742549615345664 2017-04-30 17:59:13            Facebook
# 26   858732591859605505 2017-04-30 17:19:39            Facebook
# 27   858681520621572096 2017-04-30 13:56:42            Facebook
# 28   858588558298423297 2017-04-30 07:47:18            Facebook
# 29   858588015488315392 2017-04-30 07:45:09            Facebook
# ..                  ...                 ...                 ...
# 370  854695280826101762 2017-04-19 13:56:49  Twitter for iPhone
# 371  854659816366764032 2017-04-19 11:35:53  Twitter for iPhone
# 372  854658292655763458 2017-04-19 11:29:50  Twitter for iPhone
# 373  854397185143779329 2017-04-18 18:12:17  Twitter for iPhone
# 374  854369110343471104 2017-04-18 16:20:43  Twitter for iPhone
# 375  854368738862411778 2017-04-18 16:19:15  Twitter for iPhone
# 376  854368715785330688 2017-04-18 16:19:09  Twitter for iPhone
# 377  854368708285878273 2017-04-18 16:19:08  Twitter for iPhone
# 378  854368693723312129 2017-04-18 16:19:04  Twitter for iPhone
# 379  854368309722181632 2017-04-18 16:17:33  Twitter for iPhone
# 380  854360496824365059 2017-04-18 15:46:30  Twitter for iPhone
# 381  854079482659000321 2017-04-17 21:09:51  Twitter for iPhone
# 382  854046373876043779 2017-04-17 18:58:17  Twitter for iPhone
# 383  854039249968128001 2017-04-17 18:29:59  Twitter for iPhone
# 384  853942241097904129 2017-04-17 12:04:30  Twitter for iPhone
# 385  853931667152674816 2017-04-17 11:22:29  Twitter for iPhone
# 386  853663798053531651 2017-04-16 17:38:04  Twitter for iPhone
# 387  853587831524139008 2017-04-16 12:36:12  Twitter for iPhone
# 388  853542701026947073 2017-04-16 09:36:52  Twitter for iPhone
# 389  853385937484754944 2017-04-15 23:13:57  Twitter for iPhone
# 390  853375730889129984 2017-04-15 22:33:23  Twitter for iPhone
# 391  853374834427953154 2017-04-15 22:29:50  Twitter for iPhone
# 392  853374223913537536 2017-04-15 22:27:24  Twitter for iPhone
# 393  853371879687688193 2017-04-15 22:18:05  Twitter for iPhone
# 394  853368977627787265 2017-04-15 22:06:33  Twitter for iPhone
# 395  853335274964824065 2017-04-15 19:52:38  Twitter for iPhone
# 396  853332959864258562 2017-04-15 19:43:26  Twitter for iPhone
# 397  853330197512323073 2017-04-15 19:32:27  Twitter for iPhone
# 398  853329733437804544 2017-04-15 19:30:37  Twitter for iPhone
# 399  853329675103465474 2017-04-15 19:30:23  Twitter for iPhone
#
#                                             tweet_text  twitter_id
# 0                              https://t.co/xXB9UH9wRv    24858289
# 1    I posted a new video to Facebook https://t.co/...    24858289
# 2                              https://t.co/IXBfbR5IEs    24858289
# 3    Ho aiutato  automobilisti nei paraggi segnalan...    24858289
# 4                              https://t.co/wgjhLB5oTs    24858289
# 5                              https://t.co/otKeRMrann    24858289
# 6    Ho aiutato  automobilisti nei paraggi segnalan...    24858289
# 7    Ho aiutato  automobilisti nei paraggi segnalan...    24858289
# 8                              https://t.co/rANNhPHLRO    24858289
# 9                              https://t.co/mclpa9sWbT    24858289
# 10   Buona Sfortuna - Lo Stato Sociale https://t.co...    24858289
# 11                             https://t.co/oFkzgQusVI    24858289
# 12                             https://t.co/8GfHy350Rl    24858289
# 13                             https://t.co/i39zR3xNKU    24858289
# 14                             https://t.co/IqbLqxycpm    24858289
# 15                             https://t.co/sFnWHEvR1s    24858289
# 16                             https://t.co/RscIHAMfqE    24858289
# 17                             https://t.co/TQjQmrIcyG    24858289
# 18                             https://t.co/crh2HKad3H    24858289
# 19                             https://t.co/P3qefJX0W7    24858289
# 20                             https://t.co/ELeGeCZ8ZM    24858289
# 21                             https://t.co/yMLTYtn2Xw    24858289
# 22                             https://t.co/rAs12FnRJ8    24858289
# 23                             https://t.co/JmhNwTM2Oj    24858289
# 24                             https://t.co/DW0FhD3Hja    24858289
# 25                             https://t.co/FXfw7dfkwO    24858289
# 26                             https://t.co/lSJvt0bhH7    24858289
# 27                             https://t.co/54Z1mgxBoy    24858289
# 28   IKEA Responds To Balenciaga’s $2,145 Bag That ...    24858289
# 29                             https://t.co/NBXjo3J5q9    24858289
# ..                                                 ...         ...
# 370  Domani sera non perdete il #mauriziocostanzosh...    33212890
# 371  RT @GraziaLuna_: Non voglio un'abitudine, ma g...    33212890
# 372  RT @daariannatv2000: .@RealBouchra @ElisaDospi...    33212890
# 373  @TorrisiLaura Strano sister che stai mangiando...    33212890
# 374  RT @Michaelangel260: @ElisaDospina @RaiUno @vi...    33212890
# 375  RT @carisbrook5: @ElisaDospina @RaiUno @vitain...    33212890
# 376  RT @fiorucci82: @ElisaDospina tra poco ti segu...    33212890
# 377  RT @Franci_Baglioni: @ElisaDospina @vitaindire...    33212890
# 378  RT @maury_1926: @ElisaDospina @RaiUno @vitaind...    33212890
# 379  RT @vegastarsocial: Tra poco @ElisaDospina @vi...    33212890
# 380  Vi aspetto alle 18 su @RaiUno a @vitaindiretta...    33212890
# 381  RT @ilcontenudo: C'è sempre un po' estate sull...    33212890
# 382  RT @robuovo: chissà quante volte non ci siamo ...    33212890
# 383  Quando ti senti giù di morale pensa a chi sta ...    33212890
# 384  RT @Vertigine76: @ElisaDospina #HappyEasterMon...    33212890
# 385  L'unico modo per risultare presentabili a #Pas...    33212890
# 386  Capisci che la TV è al collasso quando anche i...    33212890
# 387  Ieri così,oggi rotolo.In questa giornata ho ca...    33212890
# 388  In due mesi ho perso due chili ed è bastato un...    33212890
# 389  RT @YonhapNews: (URGENT) N. Korea's attempted ...    33212890
# 390  Comunque io @MarroneEmma l'avrei presa dalla p...    33212890
# 391  @frafacchinetti Abbiamo già detto che deve vin...    33212890
# 392  All'improvviso #Amici16 diventa #Mistero e #St...    33212890
# 393  @fraversion Dovrebbero essere sempre gli stess...    33212890
# 394  Metto su #amici16 e vedo #Pomeriggio5 condotto...    33212890
# 395  I maestri di #BallandoConLeStelle potrebbero e...    33212890
# 396  Ha ragione @RudyZerbi :i ragazzi fanno un perc...    33212890
# 397  RT @franco_sala: @ElisaDospina @fraversion Anz...    33212890
# 398  @franco_sala @fraversion Capito? .... del mond...    33212890
# 399  RT @franco_sala: @fraversion @ElisaDospina Scu...    33212890
#
# [400 rows x 5 columns]

# %% [markdown]
# <li>Calculate the ratio of the number of URLs to the number of tweets (|URLs|/|tweets|).</li>

# %%
def url_ratio(user_id):
    """
    calculate the percentage of Tweets containing URLs
    
    Argument: tweets_df
    
    Return: tweets_url_ratio
    """
    user_tweets = pd.read_csv(user_id + "_tweets.csv")
    tweets_url_ratio = sum(user_tweets['tweet_text'].str.contains("http:") == True)/len(user_tweets['tweet_text'])
    return str('{0:.4f}'.format(100 * tweets_url_ratio)) + '%'

# %%
url_ratio("33212890")
# Out:
# '0.0930%'

# %% [markdown]
# <li>Calculate the ratio of the number of unique URLs to the number of tweets (|unique URLs|/|tweets|).</li>

# %%
def url_unique_ratio(user_id):
    """
    calculate the ratio of the number of unique URLs
    
    Argument: tweets_df
    
    Return: url_ratio
    """
    user_tweets = pd.read_csv(user_id + "_tweets.csv")
    # find all the urls using regular expression
    urls = [re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', tweets) for tweets in user_tweets['tweet_text']]
    # flatten a list of lists
    urls_flatten = flatten(urls)
    # get the first two parts of the url
    urls_split = [u.split('/')[0:3] for u in urls_flatten]
    
    # find the unique urls
    # explain this??
    urls_unique = [list(u) for u in set(tuple(u) for u in urls_split)]
    url_unique= len(urls_unique)
    tweet_total = len(user_tweets['tweet_text'])
    url_ratio = url_unique/tweet_total
    return str('{0:.4f}'.format(100 * url_ratio)) + '%'

# %%
url_unique_ratio("33212890")
# Out:
# '0.1550%'

# %% [markdown]
# <li> Calculate the hashtag ratio</li>

# %%
def hashtag_ratio(user_id):
    """
    calculate the hashtag ratio
    
    Argument: tweets_df
    
    Return: hashtag ratio
    """
    user_tweets = pd.read_csv(user_id + "_tweets.csv")
    hashtag_ratio = 100 *(sum(user_tweets['tweet_text'].str.contains("#"))/len(user_tweets['tweet_text']))
    return str('{0:.2f}'.format(hashtag_ratio)) + '%'

# %%
hashtag_ratio("33212890")
# Out:
# '56.23%'

# %% [markdown]
# <li> Calculate the ratio of the number of @usernames [3]</li>

# %%
def username_ratio(user_id):
    """
    calculate the username ratio
    
    Argument: tweets_df
    
    Return: username ratio
    """
    user_tweets = pd.read_csv(user_id + "_tweets.csv")
    username_ratio = 100 *(sum(user_tweets['tweet_text'].str.contains("@"))/len(user_tweets['tweet_text']))
    return str('{0:.2f}'.format(username_ratio)) + '%'

# %%
username_ratio("33212890")
# Out:
# '76.78%'

# %% [markdown]
# <li>The ratio of the number of unique @usernames [3]</li>

# %%
def username_unique_ratio(user_id):
    """
    calculate the ratio of the number of unique @usernames
    
    Argument: tweets_df
    
    Return: username_unique_ratio
    """
    user_tweets = pd.read_csv(user_id + "_tweets.csv")
    username = [re.findall('@([A-Za-z0-9_]+)', tweets) for tweets in user_tweets['tweet_text']]
    # flatten a list of lists
    username_flatten = flatten(username)
    username_unique = set(username_flatten)
    user_unique= len(username_unique)
    # total number of users that were being @, not all the tweets
    tweet_total = len(user_tweets['tweet_text'])
    user_ratio = user_unique/tweet_total
    return str('{0:.4f}'.format(100 * user_ratio)) + '%'

# %%
username_unique_ratio("33212890")
# Out:
# '38.9337%'

# %%
new_traditional_spambots_3_tweets = pd.read_csv("new_traditional_spambots_3_tweets.csv")

# %%
tweets_df = new_traditional_spambots_3_tweets

# %%
test = tweets_df[tweets_df['twitter_id'] == 325403988]

# %%
test
# Out:
#     Unnamed: 0            tweet_id     tweet_created_at  \
# 0            0  108826506024849408  2011-08-31 09:00:35
# 1            1  108826192748097537  2011-08-31 08:59:20
# 2            2  108825876396908544  2011-08-31 08:58:05
# 3            3  108825529519579136  2011-08-31 08:56:42
# 4            4  108825174769545216  2011-08-31 08:55:18
# 5            5  108824855058710528  2011-08-31 08:54:01
# 6            6  108824494516338689  2011-08-31 08:52:36
# 7            7  108824143327281152  2011-08-31 08:51:12
# 8            8  108823768335519745  2011-08-31 08:49:42
# 9            9  108823379582259200  2011-08-31 08:48:10
# 10          10  108823017576075264  2011-08-31 08:46:43
# 11          11  108822657163735040  2011-08-31 08:45:17
# 12          12  108822264086147072  2011-08-31 08:43:44
# 13          13  108821941032468480  2011-08-31 08:42:27
# 14          14  108821560382599168  2011-08-31 08:40:56
# 15          15  108821206274281472  2011-08-31 08:39:32
# 16          16  108820929886429184  2011-08-31 08:38:26
# 17          17  108820635748278272  2011-08-31 08:37:16
# 18          18  108820212828213249  2011-08-31 08:35:35
# 19          19  108819867892854784  2011-08-31 08:34:12
# 20          20  108819604570247168  2011-08-31 08:33:10
# 21          21  108819341251837952  2011-08-31 08:32:07
# 22          22  108819027803111424  2011-08-31 08:30:52
# 23          23  108818654480707584  2011-08-31 08:29:23
# 24          24  108818261340200960  2011-08-31 08:27:49
# 25          25  108817893793349632  2011-08-31 08:26:22
# 26          26  108817488275447808  2011-08-31 08:24:45
# 27          27  108817116202934272  2011-08-31 08:23:16
# 28          28  108816805593751552  2011-08-31 08:22:02
# 29          29  108816525787529216  2011-08-31 08:20:56
# 30          30  108816127714541568  2011-08-31 08:19:21
# 31          31  108815707269115904  2011-08-31 08:17:40
# 32          32  108815411004440576  2011-08-31 08:16:30
# 33          33  108815122901905408  2011-08-31 08:15:21
# 34          34  108814755338256384  2011-08-31 08:13:54
# 35          35  108814449426710528  2011-08-31 08:12:41
# 36          36  108814063139684352  2011-08-31 08:11:08
# 37          37  108813665293189120  2011-08-31 08:09:34
# 38          38  108813259850792960  2011-08-31 08:07:57
# 39          39  108812938210586624  2011-08-31 08:06:40
# 40          40  108812662506389504  2011-08-31 08:05:35
# 41          41  108812343198236672  2011-08-31 08:04:18
# 42          42  108811941195165696  2011-08-31 08:02:43
# 43          43  108811543122165760  2011-08-31 08:01:08
# 44          44  108811225625919488  2011-08-31 07:59:52
# 45          45  108810891226660864  2011-08-31 07:58:32
# 46          46  108810593468809216  2011-08-31 07:57:21
# 47          47  108810185623089152  2011-08-31 07:55:44
#
#                                            tweet_text  twitter_id
# 0                      @ayesweetz http://t.co/muLal67   325403988
# 1                      @Tawneeeee http://t.co/muLal67   325403988
# 2                  @what_it_is_KP http://t.co/muLal67   325403988
# 3                     @unrealfred http://t.co/muLal67   325403988
# 4                     @beardedotp http://t.co/muLal67   325403988
# 5                        @mtygris http://t.co/muLal67   325403988
# 6                 @BandBAberfeldy http://t.co/muLal67   325403988
# 7                   @Adam_steward http://t.co/muLal67   325403988
# 8                     @aaAdeeNnnn http://t.co/muLal67   325403988
# 9                        @s_nadan http://t.co/muLal67   325403988
# 10                 @Anita_Chauhan http://t.co/muLal67   325403988
# 11                  @caralouise_x http://t.co/muLal67   325403988
# 12                @CarolineGrimes http://t.co/EcQwUeK   325403988
# 13                     @druchunas http://t.co/EcQwUeK   325403988
# 14                     @AmyyyyyJo http://t.co/EcQwUeK   325403988
# 15                @BronxBomber918 http://t.co/EcQwUeK   325403988
# 16                    @msbathgate http://t.co/EcQwUeK   325403988
# 17  “AZaeProduction: Aint Yall Tired Of Videos Wit...   325403988
# 18                 @melissaduffyy http://t.co/EcQwUeK   325403988
# 19                @cartwrightowen http://t.co/EcQwUeK   325403988
# 20                   @andresiuske http://t.co/EcQwUeK   325403988
# 21                  @underRATEDx3 http://t.co/EcQwUeK   325403988
# 22                     @PeteBarks http://t.co/EcQwUeK   325403988
# 23               @0hMyBieberFever http://t.co/EcQwUeK   325403988
# 24                   @Lord_Arkaig http://t.co/EcQwUeK   325403988
# 25                        @pitani http://t.co/EcQwUeK   325403988
# 26                  @beccathomas_ http://t.co/EcQwUeK   325403988
# 27               @LotusFlowerMuse http://t.co/EcQwUeK   325403988
# 28                    @mr_oglesby http://t.co/EcQwUeK   325403988
# 29                  @starr_b_supd http://t.co/h4tieYE   325403988
# 30               @MiixedMamiiAyee http://t.co/h4tieYE   325403988
# 31  tomorrow's my birthday, AND the carter 4 comes...   325403988
# 32                   @HelenSRambo http://t.co/h4tieYE   325403988
# 33                       @teeera_ http://t.co/h4tieYE   325403988
# 34  Thanks Ash! RT AshleyRochelle7: Happy Birthday...   325403988
# 35                     @leanneliz http://t.co/h4tieYE   325403988
# 36               @josefranciscojo http://t.co/h4tieYE   325403988
# 37                               No second guesseVejn   325403988
# 38                   @a_mcghee706 http://t.co/h4tieYE   325403988
# 39                                   My_ShirtOff 1mND   325403988
# 40                    @varantonio http://t.co/h4tieYE   325403988
# 41                      @_David_G http://t.co/h4tieYE   325403988
# 42                @heytherekirsty http://t.co/h4tieYE   325403988
# 43               @meganfeyereisen http://t.co/h4tieYE   325403988
# 44  woodelijah just watched Beastie boys fights/re...   325403988
# 45                @LeslieDeCosier http://t.co/h4tieYE   325403988
# 46                @sharonlawrence http://t.co/h4tieYE   325403988
# 47                 @s0ulbeautiful http://t.co/h4tieYE   325403988

# %%
def extract_words(tweets_df, user_id):
    user_tweets = tweets_df.loc[tweets_df['twitter_id'] == 2310064794]
    username = [re.findall('@([A-Za-z0-9_]+)', tweets) for tweets in user_tweets['tweet_text']]
    hashtag = [re.findall(r"#(\w+)", tweets) for tweets in user_tweets['tweet_text']]
    urls = [re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', tweets) for tweets in user_tweets['tweet_text']]
    final_tweets = [tweets.decode('unicode_escape').encode('ascii','ignore') for tweets in user_tweets['tweet_text']]
    stop = stopwords.words('english')
    delete_list = [username, hashtag, urls]
    delete_list = delete_list + stop
    delete_flatten = flatten(delete_list)
    result = [tweet for tweet in final_tweets if tweet not in delete_flatten]
    return result

# %%
### Question 1: How to remove unnecessary words

# get the tweets for a certain user (User ID: 2310064794)
user_id = 33212890
user_tweets = pd.read_csv(user_id + "_tweets.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-96cc6c3c52bf> in <module>()
#       3 # get the tweets for a certain user (User ID: 2310064794)
#       4 user_id = 33212890
# ----> 5 user_tweets = pd.read_csv(user_id + "_tweets.csv")
#       6 user_tweets = user_tweets.split()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# use regular expression to find the username, hashtag, urls
username = [re.findall('@([A-Za-z0-9_]+)', tweets) for tweets in user_tweets['tweet_text']]
hashtag = [re.findall(r"#(\w+)", tweets) for tweets in user_tweets['tweet_text']]
urls = [re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', tweets) for tweets in user_tweets['tweet_text']]
# delete the special characters from the tweets
final_tweets = [tweets.decode('unicode_escape').encode('ascii','ignore') for tweets in user_tweets['tweet_text']]
# get a list of stop words
stop = stopwords.words('english')
delete_list = [username, hashtag, urls]
# create a list of items that need to be deleted
delete_list = delete_list + stop
delete_flatten = flatten(delete_list)
# find the important words
important_words = filter(lambda words: words not in delete_flatten, final_tweets)

# %%
important_words
# Out:
# ['All the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/Oc5xKL4x9B https://t.co/Kr4D4PIuJe',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/4qQ3ZD2FcP https://t.co/eTdfvCB2c7',
#  'Great fun watch  check it out   @  slappie.us ( https://t.co/ULvq9abRP4 ) #watch #fun  #ThursdayThoughts https://t.co/hGk1Fk0qW6',
#  'JOB ALERT #IT #job #hiring     Senior .Net Developer    #developer  https://t.co/ZkOuqfK07V https://t.co/HuPQCyl0f9',
#  ' https://t.co/xLO5DreL9u  https://t.co/W7v5EmtJs3 https://t.co/hXxH5CXxLS',
#  'Top Companies are on  https://t.co/xLO5DreL9u  https://t.co/eMvmH55mtZ https://t.co/8HVvyuPk4E',
#  'Big names are on  https://t.co/xLO5DreL9u  https://t.co/HuWDvD7goG https://t.co/1qQS9dvqY1',
#  'Search and apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/wwcm1ilRJQ https://t.co/V27zyNzLK9',
#  'Featured by Entrepreneur Magazine https://t.co/IAOLd2nqWl https://t.co/3sG0461CNq',
#  'Just look who uses  https://t.co/xLO5DreL9u  https://t.co/T61bCJyRFD https://t.co/67ATI4KO1S',
#  'Save time &amp; Get Hired  https://t.co/xLO5DreL9u  https://t.co/prOJrejvLS https://t.co/fqSCakdUvq',
#  'Be the First to see the Newest IT Jobs https://t.co/pGltHQokyw https://t.co/oUON82AaY6',
#  'The Smarter Way to Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/pu1W2oLeBs https://t.co/8F7FgmpyJt',
#  'Search thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/U6qFcEqYPj https://t.co/hHrFsZbc1G',
#  '#jobalert #IT Search thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/6gspEWuY9a #hire #ITJobPro https://t.co/vDYSohgJtb',
#  'Thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/cQpL8kBU3s https://t.co/HAbi7t7lyU',
#  '#jobalert #IT Search and apply https://t.co/9JAjvLPHnm #hire #ITJobPro https://t.co/1mnIocYFXQ',
#  '#jobalert #IT Best &amp; Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/VPx1drgJNk #hire #ITJobPro https://t.co/Ca9jHLQRok',
#  '#jobalert #IT Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/ospbXor3hT #hire https://t.co/DlGvBxoPbq',
#  '#jobalert #IT  Get Hired  https://t.co/IQ6Jmtnyi0 #hire #ITJobPro https://t.co/EFQlRWxtvZ',
#  '#jobalert #IT See the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/Az32elkNLp #hire #ITJobPro https://t.co/qZS9XUVXhO',
#  '#jobalert #IT Apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/vHIK04lOfT #hire #ITJobPro https://t.co/dyYVTCqS8A',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/srziFGynUm #hire #ITJobPro https://t.co/5cHDla0WLX',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/VRn8XLKi27 #hire #ITJobPro https://t.co/7MLJUaVjQa',
#  '#jobalert #IT The Technology Job Site https://t.co/sZ5NZDy03f #hire #ITJobPro https://t.co/Hd2LYDs3sD',
#  '#jobalert #IT Want Hired by the Biggest names  https://t.co/xLO5DreL9u  https://t.co/8NSYCKmHtr #hire https://t.co/wQFGixVQHC',
#  '#jobalert #IT The most searched IT Job site in the US https://t.co/J3uwqpUWXA #hire #ITJobPro https://t.co/kv1UmGQ2WS',
#  'See the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/yrx5os4MnB https://t.co/WFTc9AbV3j',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/PiCIuPkYOB #hire #ITJobPro https://t.co/71QdDn0ebI',
#  '#jobalert #IT Just look who uses  https://t.co/xLO5DreL9u  https://t.co/GkIpCBVCE9 #hire #ITJobPro https://t.co/YmihAVD3Id',
#  '#jobalert #IT Be the First to see the Newest IT Jobs https://t.co/dQzpSSDc0j #hire #ITJobPro https://t.co/3RH09yb9bZ',
#  '#jobalert #IT Big names are on  https://t.co/xLO5DreL9u  https://t.co/xHfHnyRxWa #hire #ITJobPro https://t.co/TYrDzWLmVJ',
#  '#jobalert #IT  https://t.co/xLO5DreL9u  https://t.co/bBeZVpM1rh #hire #ITJobPro https://t.co/LLJAyJx8NK',
#  '#jobalert #IT Why search multiple sites  https://t.co/xLO5DreL9u  https://t.co/AgJ0AbyVUk #hire #ITJobPro https://t.co/XEkypZcoIb',
#  '#jobalert #IT Most Popular Technology Job Site https://t.co/SM3dkOGZjE #hire #ITJobPro https://t.co/54KySrz4Dj',
#  '#jobalert #IT  Get Hired  https://t.co/aYOBA4d00X #hire #ITJobPro',
#  '#jobalert #IT The Smarter Way to Get Hired by the Biggest names are on  https://t.co/tI5tWTPawt #hire #ITJobPro https://t.co/OqryyNsBie',
#  '#jobalert #IT Fastest Hires are on  https://t.co/xLO5DreL9u  https://t.co/gc16h33yef #hire #ITJobPro https://t.co/4udQ8Xn57s',
#  '#jobalert #IT Top Companies are on  https://t.co/xLO5DreL9u  https://t.co/KLQhbZHuNY #hire #ITJobPro https://t.co/2GsFU0XQGb',
#  'ITJobPro as Most Popular Tech Job Site https://t.co/jJ7KwBaIIk https://t.co/qU732X7xCi',
#  '#jobalert #IT Featured by Entrepreneur Magazine https://t.co/tfxDTfva7q #hire #ITJobPro https://t.co/SrvnWrQNw4',
#  '#jobalert #IT ITJobPro as Most Popular Tech Job Site https://t.co/hU6KWnloAO #hire #ITJobPro https://t.co/CcBdic4i54',
#  '#jobalert #IT Save time &amp; Get Hired  https://t.co/xLO5DreL9u  https://t.co/4vGAv0V31W #hire #ITJobPro https://t.co/yRXQ3TckJ9',
#  '#jobalert #IT Get Hired on ITJobPro https://t.co/Ey4xoKpshC #hire #ITJobPro https://t.co/rqf2djsEsg',
#  '#jobalert #IT Who uses  https://t.co/xLO5DreL9u  https://t.co/IIxuOqTdQH #hire #ITJobPro https://t.co/ZPPKwXmTfw',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/vpGH8FAc5W #hire #ITJobPro https://t.co/GI8zgCURjE',
#  '#jobalert #IT  https://t.co/xLO5DreL9u  https://t.co/Fih6fTkbM9 #hire #ITJobPro https://t.co/DXjwywBfKP',
#  '#jobalert #IT IT Recruiters https://t.co/z9SltE3pz7 #hire #ITJobPro https://t.co/9kNyYxFXoN',
#  '#jobalert #IT Thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/IhrTYWWsm2 #hire #ITJobPro https://t.co/tfTzlPX0me',
#  '#jobalert #IT Search and apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/bTUDUBE4Qe #hire https://t.co/fZwSGAGUOb',
#  '#jobalert #IT All the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/OxMPB53j26 #hire #ITJobPro https://t.co/vB3uAC3DoV',
#  'Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/v341K8DzKm https://t.co/7zwbzQOjkx',
#  '#jobalert #IT Biggest Hires are on  https://t.co/xLO5DreL9u  https://t.co/p0JDops4Ds #hire #ITJobPro https://t.co/7q9S6R4qzP',
#  'Search and apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/5PPJ97Yig8 https://t.co/URzyOSwqc2',
#  'Big names are on  https://t.co/xLO5DreL9u  https://t.co/SoQgo1l16i https://t.co/N3kkMLrupK',
#  'Best &amp; Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/4F2WJCItVd https://t.co/JkqR0UOGwZ',
#  ' https://t.co/xLO5DreL9u  https://t.co/0Lu1upHqUq https://t.co/HuKPehusBt',
#  'See the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/e48dUne6gU https://t.co/CP7vYBkBVd',
#  'The Technology Job Site https://t.co/hd1migZvcB https://t.co/OW8RrpfKDG',
#  'Thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/Wo6NzBMs1r https://t.co/5YGa79ecES',
#  'Get Hired on ITJobPro https://t.co/CO9OQrGsnF https://t.co/sJe0Xy1hR2',
#  'ITJobPro as Most Popular Tech Job Site https://t.co/e9n9XxJP8B https://t.co/Wik6PzpZGn',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/69A9yXlXDT https://t.co/BWMEURgmCb',
#  'Biggest Hires are on  https://t.co/xLO5DreL9u  https://t.co/9sQkIllBVq https://t.co/b7XtfAYa4W',
#  'IT Recruiters https://t.co/ayMediPWnS https://t.co/Cn5VDNldZc',
#  'Search thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/4ftEuudS1j https://t.co/v9nx8KuvkA',
#  ' Get Hired  https://t.co/9tbQnNcAfj https://t.co/Edn5fqTlNU',
#  'Apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/Fa4DPC1Q5c https://t.co/ynRb5I47FS',
#  'All the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/F58GQAr6ho https://t.co/kZ4Df3bHK9',
#  'Just look who uses  https://t.co/xLO5DreL9u  https://t.co/Z4pa5COuMH https://t.co/yZNug4VOPN',
#  'Fastest Hires are on  https://t.co/xLO5DreL9u  https://t.co/mELrJulsk8 https://t.co/T5moukDr1f',
#  'Search and apply https://t.co/tT0TaMIFRS https://t.co/SkX2Cg79n8',
#  'Most Popular Technology Job Site https://t.co/utSUYz5Gjz https://t.co/apRreHSUSU',
#  'The Smarter Way to Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/C073yWednV https://t.co/6fqQNaGFja',
#  '#jobalert #IT Apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/E5LDTCA1aW #hire #ITJobPro https://t.co/YgeAUwQsrn',
#  'Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/NZ02ex1L4b https://t.co/MxTr1QPLNG',
#  '#jobalert #IT Search and apply https://t.co/vEu6vhCCHt #hire #ITJobPro https://t.co/MkhGXch3Vf',
#  '#jobalert #IT Biggest Hires are on  https://t.co/xLO5DreL9u  https://t.co/4a4omrPTMg #hire #ITJobPro https://t.co/t7ZOMxNQjm',
#  '#jobalert #IT ITJobPro as Most Popular Tech Job Site https://t.co/4DdxExsevD #hire #ITJobPro https://t.co/Pe0k7Ux0m5',
#  '#jobalert #IT Want Hired by the Biggest names  https://t.co/xLO5DreL9u  https://t.co/3VwE6IABm4 #hire https://t.co/ztfVQyNvTB',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/rKPYlSUepS #hire #ITJobPro https://t.co/mDoKd18TGz',
#  '#jobalert #IT Best &amp; Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/y0df45dPeQ #hire #ITJobPro https://t.co/V1yHAB1gDP',
#  '#jobalert #IT Most Popular Technology Job Site https://t.co/sRYt3BZj8m #hire #ITJobPro https://t.co/7XHzlPUop0',
#  '#jobalert #IT Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/Il98zF6e3E #hire https://t.co/6ca6yXXYLX',
#  '#jobalert #IT IT Recruiters https://t.co/k7SBkqbTBJ #hire #ITJobPro https://t.co/BaOIwP7LBu',
#  '#jobalert #IT Be the First to see the Newest IT Jobs https://t.co/8FXCAr6eNA #hire #ITJobPro https://t.co/AI7SrhDi63',
#  '#jobalert #IT The Technology Job Site https://t.co/MdPlz5YkbK #hire #ITJobPro https://t.co/E9rWs24P5V',
#  'Be the First to see the Newest IT Jobs https://t.co/WYRS0KrVhr https://t.co/yvbDj8dlRF',
#  '#jobalert #IT Big names are on  https://t.co/xLO5DreL9u  https://t.co/HRxhlUu7DE #hire #ITJobPro https://t.co/xwHdGydMgk',
#  '#jobalert #IT See the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/4HMW91cjc7 #hire #ITJobPro https://t.co/l8FmLPfsuJ',
#  '#jobalert #IT Who uses  https://t.co/xLO5DreL9u  https://t.co/q6KIMaoDzS #hire #ITJobPro https://t.co/Y63eOL8tgL',
#  '#jobalert #IT The most searched IT Job site in the US https://t.co/Bsx1ecfWqJ #hire #ITJobPro https://t.co/Ht2XVi2dTp',
#  '#jobalert #IT All the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/jg3nmDv6lI #hire #ITJobPro https://t.co/qgCV5zxEB4',
#  '#jobalert #IT  Get Hired  https://t.co/rA9cq9cXm8 #hire #ITJobPro https://t.co/a5zTyaxVry',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/Fm6EBItSdx #hire #ITJobPro https://t.co/VacVLtRkCk',
#  '#jobalert #IT Featured by Entrepreneur Magazine https://t.co/Qksp007V1t #hire #ITJobPro https://t.co/qzC4QBB2Te',
#  '#jobalert #IT Search thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/wyqpDKHhje #hire #ITJobPro https://t.co/v3ImeuoGqT',
#  '#jobalert #IT  https://t.co/xLO5DreL9u  https://t.co/C070eIsgMV #hire #ITJobPro https://t.co/k01t2qRzVZ',
#  '#jobalert #IT Save time &amp; Get Hired  https://t.co/xLO5DreL9u  https://t.co/hDuBSIsVJK #hire #ITJobPro https://t.co/uJMwU81TEM',
#  'Featured by Entrepreneur Magazine https://t.co/AM8Ld6lNcr https://t.co/qYDIfWVhlA',
#  '#jobalert #IT Why search multiple sites  https://t.co/xLO5DreL9u  https://t.co/rpAuDeBmDM #hire #ITJobPro https://t.co/nNL5FRShbl',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/G5KAR43GA9 #hire #ITJobPro https://t.co/JWDDsvsMcD',
#  '#jobalert #IT Fastest Hires are on  https://t.co/xLO5DreL9u  https://t.co/Nu8AArwggD #hire #ITJobPro https://t.co/J5beR0M4D3',
#  '#jobalert #IT The Smarter Way to Get Hired by the Biggest names are on  https://t.co/rf6E2sm4ai #hire #ITJobPro https://t.co/WkIk38msxJ',
#  '#jobalert #IT Top Companies are on  https://t.co/xLO5DreL9u  https://t.co/XE3ys9nBhA #hire #ITJobPro https://t.co/ekShezuvNM',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/BNK0qrRuIR #hire #ITJobPro https://t.co/Al1vKnAgzj',
#  '#jobalert #IT  https://t.co/xLO5DreL9u  https://t.co/uBKRMh3oUj #hire #ITJobPro https://t.co/OqZTwhU2ae',
#  '#jobalert #IT Get Hired on ITJobPro https://t.co/4EwCwllebn #hire #ITJobPro https://t.co/ABrYIpFhTa',
#  '#jobalert #IT Thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/6fFE3tUBNx #hire #ITJobPro https://t.co/mZseJfAaFu',
#  '#jobalert #IT Just look who uses  https://t.co/xLO5DreL9u  https://t.co/i9hKrsGikB #hire #ITJobPro https://t.co/ZYZDJPuQo1',
#  '#jobalert #IT  Get Hired  https://t.co/pM555GsVkl #hire #ITJobPro',
#  'Save time &amp; Get Hired  https://t.co/xLO5DreL9u  https://t.co/z3DNycPaEq https://t.co/3DdIiMrah6',
#  '#jobalert #IT Search and apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/oEAgi350Ik #hire https://t.co/dhJHYUlFfJ',
#  'IT Recruiters https://t.co/qNr6wSIJPW https://t.co/izh63yjfds',
#  ' Get Hired  https://t.co/M2NTuo3DDR https://t.co/n921vjFzsO',
#  'Search and apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/PzttxEw1G8 https://t.co/a98G7wWCOd',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/VwzX1kdm0D https://t.co/nP5lAXaEpQ',
#  ' https://t.co/xLO5DreL9u  https://t.co/FHf5p6tyap https://t.co/S5fT5XHC4y',
#  'ITJobPro as Most Popular Tech Job Site https://t.co/73mknccodR https://t.co/QGDQu1Zl3S',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/NU1G9FXMeg https://t.co/CXLCewPmsl',
#  'Search and apply https://t.co/HDeko6atgD https://t.co/lrYO3I9GP3',
#  ' Get Hired  https://t.co/Mw3Hh02kSD',
#  '#jobalert #IT ITJobPro as Most Popular Tech Job Site https://t.co/4Mfb78UGUO #hire #ITJobPro https://t.co/J6W5HWIfm0',
#  '#jobalert #IT Just look who uses https://t.co/EWP8cfOqoh  https://t.co/JVLQ2tnOAV #hire #ITJobPro https://t.co/DtwIVaO5Rh',
#  '#jobalert #IT Search and apply https://t.co/DQrRADWOQ7 #hire #ITJobPro https://t.co/H4L1oJoWND',
#  'Featured by Entrepreneur Magazine https://t.co/iTU9dxVhF2 https://t.co/e94avakeWt',
#  '#jobalert #IT  Get Hired  https://t.co/8HgT4Jacgd #hire #ITJobPro',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/l8hf08O1PU #hire #ITJobPro https://t.co/Jgz23kD7LX',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/eYnGGHpNP6 #hire #ITJobPro https://t.co/E4y2RnP4QB',
#  '#jobalert #IT The most searched IT Job site in the US https://t.co/SkWKPjuI1I #hire #ITJobPro https://t.co/Whdkn7C1rR',
#  '#jobalert #IT  Get Hired  https://t.co/HKsWJ1gcqW #hire #ITJobPro https://t.co/MWkmJYu87f',
#  '#jobalert #IT  https://t.co/xLO5DreL9u  https://t.co/SQPChZUK5X #hire #ITJobPro https://t.co/cyrtyLQivs',
#  '#jobalert #IT Search and apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/XfoL6rVKa1 #hire https://t.co/ShZz3Rt5Gq',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/7eL9w8PQRF #hire #ITJobPro https://t.co/rVoTc4l22B',
#  '#jobalert #IT IT Recruiters https://t.co/6hywteUAIE #hire #ITJobPro https://t.co/yTvYABrWE8',
#  '#jobalert #IT Featured by Entrepreneur Magazine https://t.co/9iQjBBrT7X #hire #ITJobPro https://t.co/f3AjknnnXv',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DqXahW  https://t.co/u9e18jCOCF #hire #ITJobPro https://t.co/Z7FSYjSrCI',
#  'Be the First to see the Newest IT Jobs https://t.co/252NvXdfao https://t.co/aiSkGghyqk',
#  '#jobalert #IT Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/AUFlDGLXZt #hire https://t.co/Wj6ij8WWnU',
#  '#jobalert #IT Be the First to see the Newest IT Jobs https://t.co/5MsrNPOk34 #hire #ITJobPro https://t.co/gPTFzumCCq',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/DvgZp9325r https://t.co/MZ1JRNDWxO',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/mSZLU780FY https://t.co/zmeiaN7Tgo',
#  'Featured by Entrepreneur Magazine https://t.co/nJdzmvQpWB https://t.co/AM5FdH0cBa',
#  'Search and apply https://t.co/htABhqxjo3 https://t.co/l0SUwx1nQK',
#  'The most searched IT Job site in the US https://t.co/jTvI1EW5za https://t.co/MMt537iMXp',
#  'ITJobPro as Most Popular Tech Job Site https://t.co/cPhLgLl6ev https://t.co/htD0Bwfm54',
#  ' Get Hired  https://t.co/5UJvuyzR7G',
#  ' https://t.co/xLO5DreL9u  https://t.co/Nnvv2ksmr8 https://t.co/p3KPQCye28',
#  'IT Recruiters https://t.co/OkMd0zbWPK https://t.co/m0c4x9LdIV',
#  'Just look who uses  https://t.co/xLO5DreL9u  https://t.co/I46FRvFtLg https://t.co/M0c11b0pKA',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/dDSvo64wxs https://t.co/DMXBFh3VlH',
#  'Search and apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/DCpeGC5TTq https://t.co/KY8i8Hix6d',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/qIQfPpd71v https://t.co/AalgcI05yM',
#  'Be the First to see the Newest IT Jobs https://t.co/syfcOg4pZg https://t.co/pO8nh9CI1V',
#  '#jobalert #IT IT Recruiters https://t.co/qLndnMM1um #hire #ITJobPro https://t.co/Cp0MOyIl4g',
#  '#jobalert #IT Search and apply https://t.co/NvATXjdzqg #hire #ITJobPro https://t.co/BVjR5EHcWc',
#  '#jobalert #IT Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/fq8Nxdrhtf #hire https://t.co/YmtTrAJPxB',
#  '#jobalert #IT  Get Hired  https://t.co/g9VEBBt1QD #hire #ITJobPro https://t.co/YbObAo3RNn',
#  ' Get Hired  https://t.co/aP5OcH9K2e https://t.co/uzs17x4bCo',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/VfNrm90XEE #hire #ITJobPro https://t.co/xaWDCW0REx',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/jf20DDN95h #hire #ITJobPro https://t.co/Ze1Rp6S6sm',
#  '#jobalert #IT Just look who uses  https://t.co/xLO5DreL9u  https://t.co/MPB2ijtXXg #hire #ITJobPro https://t.co/gOsH4iXZyG',
#  '#jobalert #IT Be the First to see the Newest IT Jobs https://t.co/xcqsIaBYEw #hire #ITJobPro https://t.co/SWbbmZQpO2',
#  '#jobalert #IT  Get Hired  https://t.co/XKG0wtzUCN #hire #ITJobPro',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/D1VC0eefvs #hire #ITJobPro https://t.co/4pQHL1Y2A0',
#  '#jobalert #IT  https://t.co/xLO5DreL9u  https://t.co/lmNHYpVzJS #hire #ITJobPro https://t.co/Kcf3wuXPkb',
#  '#jobalert #IT Search and apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/8nPU7P36S1 #hire https://t.co/4iFFSZN1Ki',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/k1QmqOsad5 #hire #ITJobPro https://t.co/z52hPt562z',
#  '#jobalert #IT ITJobPro as Most Popular Tech Job Site https://t.co/xEbVrUIvIJ #hire #ITJobPro https://t.co/DHvaZAWj3k',
#  '#jobalert #IT The most searched IT Job site in the US https://t.co/B4wQ3762TD #hire #ITJobPro https://t.co/sMr3IhPgEy',
#  'Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/Wpr6UaalPt https://t.co/2EOdc5FZXj',
#  '#jobalert #IT Featured by Entrepreneur Magazine https://t.co/m6RlgpW7r2 #hire #ITJobPro https://t.co/1O6MM08jMh',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/Z20b6VAyMh https://t.co/tAmc6KlqES',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/SNWMkinckS https://t.co/HZtK3AJNIT',
#  'Search and apply https://t.co/umLtiWC0hB https://t.co/ScviOKixcZ',
#  'Be the First to see the Newest IT Jobs https://t.co/XrwKl2esAE https://t.co/CTy55UEFaQ',
#  'Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/djH8m1SwlE https://t.co/wNGWCm48nZ',
#  ' Get Hired  https://t.co/QGorl68d5f',
#  'Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/HQMxCy46Ex https://t.co/wSHXoZZI5w',
#  'Search and apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/FGJMnPI7Hj https://t.co/bKwlI69SRl',
#  'IT Recruiters https://t.co/nfwZfC2fuL https://t.co/v1C3dAJMVY',
#  ' Get Hired  https://t.co/hix2CX51nv https://t.co/A3CHH5cvhD',
#  '#jobalert #IT Get Hired by the Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/lx6DolacN7 #hire https://t.co/1Y4R2fSIy5',
#  '#jobalert #IT Featured by Entrepreneur Magazine https://t.co/wgaZtTmHjW #hire #ITJobPro https://t.co/FzgmtNzvq1',
#  '#jobalert #IT Search and apply to thousands of tech jobs on https://t.co/xLO5DreL9u https://t.co/71FKVF0hxj #hire https://t.co/su7Vcpyday',
#  '#jobalert #IT ITJobPro as Most Popular Tech Job Site https://t.co/g5E8mciT15 #hire #ITJobPro https://t.co/RqqLcppOd9',
#  ' https://t.co/xLO5DreL9u  https://t.co/ADRCu01FPX https://t.co/hcZjQ7Twer',
#  '#jobalert #IT  Get Hired  https://t.co/uUjXifrciI #hire #ITJobPro https://t.co/UGLog9Vct5',
#  '#jobalert #IT  Get Hired  https://t.co/QCSMmgRYAy #hire #ITJobPro',
#  '#jobalert #IT Search and apply https://t.co/5BWmt7EEsa #hire #ITJobPro https://t.co/Fj4Pf4dH28',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/aETTEvprvA #hire #ITJobPro https://t.co/xIhgbxCRh9',
#  '#jobalert #IT Just look who uses  https://t.co/xLO5DreL9u  https://t.co/M5GG1AmuRf #hire #ITJobPro https://t.co/GS4vt1J68F',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/dK192AhhBP #hire #ITJobPro https://t.co/wnfkkVOTmS',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/eVxt7aqjyJ #hire #ITJobPro https://t.co/NG68oZgt0j',
#  '#jobalert #IT IT Recruiters https://t.co/Q4hxXHQ0Sz #hire #ITJobPro https://t.co/1Kk1JntQY3',
#  '#jobalert #IT Be the First to see the Newest IT Jobs https://t.co/HcTx69zy93 #hire #ITJobPro https://t.co/K90PyKmPBM',
#  '#jobalert #IT Biggest names are on  https://t.co/xLO5DreL9u  https://t.co/5xVz7G6Xyw #hire #ITJobPro https://t.co/Tc8Enu6cQH',
#  '#jobalert #IT The most searched IT Job site in the US https://t.co/umhW6jGSDl #hire #ITJobPro https://t.co/jQQbFQKzLj',
#  'Just look who uses  https://t.co/xLO5DreL9u  https://t.co/n0P27aDpHY https://t.co/twAr3PYvoS',
#  '#jobalert #IT  https://t.co/xLO5DreL9u  https://t.co/A7foushU9o #hire #ITJobPro https://t.co/CLzMA6PiGG']

# %%
def comb_2(num_tweets):
    return int(factorial(num_tweets) / (factorial(2) * factorial(num_tweets - 2)))

# %%
user_tweets = tweets_df.loc[tweets_df['twitter_id'] == 2310064794]

# %% [markdown]
# <li>Tweet similarity:
# (1) $S=\frac{\sum_{p\in P}c(p)}{l_al_p}$
# where $P$ is the set of possible tweet-to-tweet combinations among any two tweets logged for a certain account, $p$ is a single pair, $c(p)$ is a function calculation the number of words two tweets share, $l_a$ is the average length of tweets posted by that user, and $l_p$ is the number of tweet combinations. A profile sending similar tweets will have a low value of S.[4]

# %%
for i in num_tweets['tweet_text']:
    for j in num_tweets['tweet_text']:
        print i + j
# Out:
# Biggest names are on ☆★☆ https://t.co/xLO5DreL9u ☆★☆ https://t.co/4qQ3ZD2FcP https://t.co/eTdfvCB2c7Biggest names are on ☆★☆ https://t.co/xLO5DreL9u ☆★☆ https://t.co/4qQ3ZD2FcP https://t.co/eTdfvCB2c7
# Biggest names are on ☆★☆ https://t.co/xLO5DreL9u ☆★☆ https://t.co/4qQ3ZD2FcP https://t.co/eTdfvCB2c7Great fun watch ⌚ check it out 😍 👉 @  slappie.us ( https://t.co/ULvq9abRP4 ) #watch #fun  #ThursdayThoughts https://t.co/hGk1Fk0qW6
# Biggest names are on ☆★☆ https://t.co/xLO5DreL9u ☆★☆ https://t.co/4qQ3ZD2FcP https://t.co/eTdfvCB2c7JOB ALERT #IT #job #hiring  💻   Senior .Net Developer   👨‍💻👩‍💻 #developer  https://t.co/ZkOuqfK07V https://t.co/HuPQCyl0f9
# Great fun watch ⌚ check it out 😍 👉 @  slappie.us ( https://t.co/ULvq9abRP4 ) #watch #fun  #ThursdayThoughts https://t.co/hGk1Fk0qW6Biggest names are on ☆★☆ https://t.co/xLO5DreL9u ☆★☆ https://t.co/4qQ3ZD2FcP https://t.co/eTdfvCB2c7
# Great fun watch ⌚ check it out 😍 👉 @  slappie.us ( https://t.co/ULvq9abRP4 ) #watch #fun  #ThursdayThoughts https://t.co/hGk1Fk0qW6Great fun watch ⌚ check it out 😍 👉 @  slappie.us ( https://t.co/ULvq9abRP4 ) #watch #fun  #ThursdayThoughts https://t.co/hGk1Fk0qW6
# Great fun watch ⌚ check it out 😍 👉 @  slappie.us ( https://t.co/ULvq9abRP4 ) #watch #fun  #ThursdayThoughts https://t.co/hGk1Fk0qW6JOB ALERT #IT #job #hiring  💻   Senior .Net Developer   👨‍💻👩‍💻 #developer  https://t.co/ZkOuqfK07V https://t.co/HuPQCyl0f9
# JOB ALERT #IT #job #hiring  💻   Senior .Net Developer   👨‍💻👩‍💻 #developer  https://t.co/ZkOuqfK07V https://t.co/HuPQCyl0f9Biggest names are on ☆★☆ https://t.co/xLO5DreL9u ☆★☆ https://t.co/4qQ3ZD2FcP https://t.co/eTdfvCB2c7
# JOB ALERT #IT #job #hiring  💻   Senior .Net Developer   👨‍💻👩‍💻 #developer  https://t.co/ZkOuqfK07V https://t.co/HuPQCyl0f9Great fun watch ⌚ check it out 😍 👉 @  slappie.us ( https://t.co/ULvq9abRP4 ) #watch #fun  #ThursdayThoughts https://t.co/hGk1Fk0qW6
# JOB ALERT #IT #job #hiring  💻   Senior .Net Developer   👨‍💻👩‍💻 #developer  https://t.co/ZkOuqfK07V https://t.co/HuPQCyl0f9JOB ALERT #IT #job #hiring  💻   Senior .Net Developer   👨‍💻👩‍💻 #developer  https://t.co/ZkOuqfK07V https://t.co/HuPQCyl0f9

# %%
user_tweets = tweets_df.loc[tweets_df['twitter_id'] == 2310064794]

# %%
num_tweets = len(user_tweets['tweet_text'])

# %%
num_tweets = user_tweets[1:4]

# %%
num_tweets['tweet_text']
# Out:
# 56501    Biggest names are on ☆★☆ https://t.co/xLO5DreL...
# 56502    Great fun watch ⌚ check it out 😍 👉 @  slappi...
# 56503    JOB ALERT #IT #job #hiring  💻   Senior .Net D...
# Name: tweet_text, dtype: object

# %% [markdown]
#
# (2) $\sum_{a,b \in set of pairs in tweets}\frac{similarity(a,b)}{|set of pairs in tweets|}$
# where the content similarity is computed using the standard cosine simility over the bag-of-word vector representation $\mathbf{V(a)}$ of the tweet content: $similarity(a,b)=\frac{\mathbf{V(a)}\mathbf{V(b)}}{|\mathbf{V(a)}||\mathbf{V(b)}|}$
# Since tweets are extremely short (140 characters or less), we consider a bag-of-words model and a sparse bigrams model. [3]</li>
